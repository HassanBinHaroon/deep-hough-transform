# %% [markdown]
# <a href="https://colab.research.google.com/github/HassanBinHaroon/deep-hough-transform/blob/main/Hanqer_Deep_Hough_Transform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Hanqer/deep-hough-transform.git
# Out:
# Cloning into 'deep-hough-transform'...
# remote: Enumerating objects: 609, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 609 (delta 16), reused 11 (delta 10), pack-reused 579
# Receiving objects: 100% (609/609), 13.86 MiB | 23.11 MiB/s, done.
# Resolving deltas: 100% (107/107), done.

# %%
# %cd deep-hough-transform/
# Out:
# /content/deep-hough-transform

# %%
# !wget http://data.kaizhao.net/projects/deep-hough-transform/NKL.zip
# Out:
# --2022-08-08 11:19:06--  http://data.kaizhao.net/projects/deep-hough-transform/NKL.zip
# Resolving data.kaizhao.net (data.kaizhao.net)... 172.67.190.95, 104.21.43.242, 2606:4700:3030::6815:2bf2, ...
# Connecting to data.kaizhao.net (data.kaizhao.net)|172.67.190.95|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://data.kaizhao.net/projects/deep-hough-transform/NKL.zip [following]
# --2022-08-08 11:19:06--  https://data.kaizhao.net/projects/deep-hough-transform/NKL.zip
# Connecting to data.kaizhao.net (data.kaizhao.net)|172.67.190.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 581179759 (554M) [application/zip]
# Saving to: ‘NKL.zip’
#
# NKL.zip             100%[===================>] 554.26M  1.98MB/s    in 9m 10s
#
# 2022-08-08 11:28:17 (1.01 MB/s) - ‘NKL.zip’ saved [581179759/581179759]

# %%
# !unzip NKL.zip -d data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/NKL/46.jpg
#   inflating: data/NKL/46.txt
#   inflating: data/NKL/460.jpg
#   inflating: data/NKL/460.txt
#   inflating: data/NKL/4600.jpg
#   inflating: data/NKL/4600.txt
#   inflating: data/NKL/4601.jpg
#   inflating: data/NKL/4601.txt
#   inflating: data/NKL/4602.jpg
#   inflating: data/NKL/4602.txt
#   inflating: data/NKL/4603.jpg
#   inflating: data/NKL/4603.txt
#   inflating: data/NKL/4604.jpg
#   inflating: data/NKL/4604.txt
#   inflating: data/NKL/4605.jpg
#   inflating: data/NKL/4605.txt
#   inflating: data/NKL/4606.jpg
#   inflating: data/NKL/4606.txt
#   inflating: data/NKL/4607.jpg
#   inflating: data/NKL/4607.txt
#   inflating: data/NKL/4608.jpg
#   inflating: data/NKL/4608.txt
#   inflating: data/NKL/4609.jpg
#   inflating: data/NKL/4609.txt
#   inflating: data/NKL/461.jpg
#   inflating: data/NKL/461.txt
#   inflating: data/NKL/4610.jpg
#   inflating: data/NKL/4610.txt
# ...

# %%
# !wget http://data.kaizhao.net/projects/deep-hough-transform/dht_r50_nkl_d97b97138.pth
# Out:
# --2022-08-08 11:28:23--  http://data.kaizhao.net/projects/deep-hough-transform/dht_r50_nkl_d97b97138.pth
# Resolving data.kaizhao.net (data.kaizhao.net)... 104.21.43.242, 172.67.190.95, 2606:4700:3030::6815:2bf2, ...
# Connecting to data.kaizhao.net (data.kaizhao.net)|104.21.43.242|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://data.kaizhao.net/projects/deep-hough-transform/dht_r50_nkl_d97b97138.pth [following]
# --2022-08-08 11:28:23--  https://data.kaizhao.net/projects/deep-hough-transform/dht_r50_nkl_d97b97138.pth
# Connecting to data.kaizhao.net (data.kaizhao.net)|104.21.43.242|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 110615645 (105M) [application/octet-stream]
# Saving to: ‘dht_r50_nkl_d97b97138.pth’
#
# dht_r50_nkl_d97b971 100%[===================>] 105.49M  4.90MB/s    in 22s
#
# 2022-08-08 11:28:46 (4.74 MB/s) - ‘dht_r50_nkl_d97b97138.pth’ saved [110615645/110615645]

# %%
# %cd model/_cdht
# Out:
# /content/deep-hough-transform/model/_cdht

# %%
# !python setup.py install --user
# Out:
# running install
# running bdist_egg
# running egg_info
# creating deep_hough.egg-info
# writing deep_hough.egg-info/PKG-INFO
# writing dependency_links to deep_hough.egg-info/dependency_links.txt
# writing top-level names to deep_hough.egg-info/top_level.txt
# writing manifest file 'deep_hough.egg-info/SOURCES.txt'
# /usr/local/lib/python3.7/dist-packages/torch/utils/cpp_extension.py:411: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# writing manifest file 'deep_hough.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# ...

# %%
# %cd ../..
# Out:
# /content/deep-hough-transform

# %%
# !python forward.py --model dht_r50_nkl_d97b97138.pth --tmp results
# Out:
# 2022-08-08 11:30:09,463 INFO Namespace(align=False, config='./config.yml', model='dht_r50_nkl_d97b97138.pth', tmp='results')
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100% 97.8M/97.8M [00:00<00:00, 287MB/s]
# 2022-08-08 11:30:14,916 INFO => loading pretrained model 'dht_r50_nkl_d97b97138.pth'
# 2022-08-08 11:30:15,056 INFO => loaded checkpoint 'dht_r50_nkl_d97b97138.pth'
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 2022-08-08 11:30:15,060 INFO Data loading done.
# ...

# %%
# !pip install POT
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 664 kB 7.1 MB/s
# ...

# %%
# !pip install Ninja
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 108 kB 7.3 MB/s
# ...

# %%
#!python --version
#!sudo apt-get update -y
#!sudo apt-get install python3.9
#!sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.7 1
#!sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.9 2
#!python --version

# %%
# !python test_nkl.py --pred results/visualize_test/ --gt data/NKL/
# Out:
# Mean P: 0.6842166184936662
# Mean R: 0.766064417762531
# Mean F: 0.7228304458943596
# F@0.95: 0.46145579498809
