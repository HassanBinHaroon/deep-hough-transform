# %% [markdown]
# <a href="https://colab.research.google.com/github/HassanBinHaroon/deep-hough-transform/blob/main/Hanqer_Deep_Hough_Transform_Train_NKL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Hanqer/deep-hough-transform.git
# Out:
# Cloning into 'deep-hough-transform'...
# remote: Enumerating objects: 609, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 609 (delta 16), reused 11 (delta 10), pack-reused 579
# Receiving objects: 100% (609/609), 13.86 MiB | 39.42 MiB/s, done.
# Resolving deltas: 100% (107/107), done.

# %%
# %cd deep-hough-transform/
# Out:
# /content/deep-hough-transform

# %%
# !wget http://data.kaizhao.net/projects/deep-hough-transform/NKL.zip
# Out:
# --2022-08-10 09:11:17--  http://data.kaizhao.net/projects/deep-hough-transform/NKL.zip
# Resolving data.kaizhao.net (data.kaizhao.net)... 104.21.43.242, 172.67.190.95, 2606:4700:3030::6815:2bf2, ...
# Connecting to data.kaizhao.net (data.kaizhao.net)|104.21.43.242|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://data.kaizhao.net/projects/deep-hough-transform/NKL.zip [following]
# --2022-08-10 09:11:17--  https://data.kaizhao.net/projects/deep-hough-transform/NKL.zip
# Connecting to data.kaizhao.net (data.kaizhao.net)|104.21.43.242|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 581179759 (554M) [application/zip]
# Saving to: ‘NKL.zip’
#
# NKL.zip             100%[===================>] 554.26M  2.40MB/s    in 3m 57s
#
# 2022-08-10 09:15:18 (2.34 MB/s) - ‘NKL.zip’ saved [581179759/581179759]

# %%
# !unzip NKL.zip -d data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/NKL/46.jpg
#   inflating: data/NKL/46.txt
#   inflating: data/NKL/460.jpg
#   inflating: data/NKL/460.txt
#   inflating: data/NKL/4600.jpg
#   inflating: data/NKL/4600.txt
#   inflating: data/NKL/4601.jpg
#   inflating: data/NKL/4601.txt
#   inflating: data/NKL/4602.jpg
#   inflating: data/NKL/4602.txt
#   inflating: data/NKL/4603.jpg
#   inflating: data/NKL/4603.txt
#   inflating: data/NKL/4604.jpg
#   inflating: data/NKL/4604.txt
#   inflating: data/NKL/4605.jpg
#   inflating: data/NKL/4605.txt
#   inflating: data/NKL/4606.jpg
#   inflating: data/NKL/4606.txt
#   inflating: data/NKL/4607.jpg
#   inflating: data/NKL/4607.txt
#   inflating: data/NKL/4608.jpg
#   inflating: data/NKL/4608.txt
#   inflating: data/NKL/4609.jpg
#   inflating: data/NKL/4609.txt
#   inflating: data/NKL/461.jpg
#   inflating: data/NKL/461.txt
#   inflating: data/NKL/4610.jpg
#   inflating: data/NKL/4610.txt
# ...

# %%
# %cd model/_cdht
# Out:
# /content/deep-hough-transform/model/_cdht

# %%
# !python setup.py build
# Out:
# running build
# running build_ext
# /usr/local/lib/python3.7/dist-packages/torch/utils/cpp_extension.py:411: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# /usr/local/lib/python3.7/dist-packages/torch/utils/cpp_extension.py:813: UserWarning: The detected CUDA version (11.1) has a minor version mismatch with the version that was used to compile PyTorch (11.3). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# building 'deep_hough' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# ...

# %%
# !python setup.py install --user
# Out:
# running install
# running bdist_egg
# running egg_info
# creating deep_hough.egg-info
# writing deep_hough.egg-info/PKG-INFO
# writing dependency_links to deep_hough.egg-info/dependency_links.txt
# writing top-level names to deep_hough.egg-info/top_level.txt
# writing manifest file 'deep_hough.egg-info/SOURCES.txt'
# /usr/local/lib/python3.7/dist-packages/torch/utils/cpp_extension.py:411: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# writing manifest file 'deep_hough.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# ...

# %%
# %cd ../..
# Out:
# /content/deep-hough-transform

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 30.1 MB/s
# ...

# %%
# !pip install POT
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 664 kB 30.3 MB/s
# ...

# %%
# !pip install Ninja
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 108 kB 26.4 MB/s
# ...

# %%
# !python data/prepare_data_NKL.py --root './data/NKL' --label './data/NKL' --save-dir './data/training/NKL_resize_100_100' --fixsize 400
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing 5429 [1501/6500]...
# Processing 437 [1502/6500]...
# Processing 4190 [1503/6500]...
# Processing 1969 [1504/6500]...
# Processing 4230 [1505/6500]...
# Processing 896 [1506/6500]...
# Processing 4423 [1507/6500]...
# Processing 5473 [1508/6500]...
# Processing 3156 [1509/6500]...
# Processing 3979 [1510/6500]...
# Processing 2442 [1511/6500]...
# Processing 5198 [1512/6500]...
# Processing 6371 [1513/6500]...
# Processing 1871 [1514/6500]...
# Processing 1260 [1515/6500]...
# Processing 6230 [1516/6500]...
# Processing 1112 [1517/6500]...
# Processing 3713 [1518/6500]...
# Processing 5416 [1519/6500]...
# Processing 5018 [1520/6500]...
# Processing 2116 [1521/6500]...
# Processing 5490 [1522/6500]...
# Processing 5079 [1523/6500]...
# Processing 3330 [1524/6500]...
# Processing 510 [1525/6500]...
# Processing 5437 [1526/6500]...
# Processing 5778 [1527/6500]...
# Processing 3371 [1528/6500]...
# ...

# %%
# !python train.py
# Out:
# 2022-08-10 09:20:19,840 INFO {'DATA': {'DIR': 'data/training/', 'VAL_DIR': 'data/training/', 'TEST_DIR': 'data/NKL', 'LABEL_FILE': 'data/training/nkl_train.txt', 'VAL_LABEL_FILE': 'data/training/nkl_val.txt', 'TEST_LABEL_FILE': 'data/training/nkl_test.txt', 'BATCH_SIZE': 8, 'WORKERS': 4}, 'OPTIMIZER': {'LR': 0.0002, 'MOMENTUM': 0.9, 'GAMMA': 0.1, 'WEIGHT_DECAY': 0.0, 'STEPS': []}, 'MODEL': {'NUMANGLE': 100, 'NUMRHO': 100, 'FIX': True, 'THRESHOLD': 0.01, 'EDGE_ALIGN': False, 'BACKBONE': 'resnet50'}, 'TRAIN': {'EPOCHS': 30, 'PRINT_FREQ': 100, 'TEST': False, 'SEED': 1997, 'GPU_ID': 0, 'DATA_PARALLEL': False, 'RESUME': None}, 'MISC': {'TMP': './result/reproduce'}}
# 2022-08-10 09:20:19,840 INFO Namespace(config='./config.yml', resume='', tmp='')
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100% 97.8M/97.8M [00:00<00:00, 239MB/s]
# ...
